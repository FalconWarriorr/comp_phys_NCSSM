# %%
import pylab

year = [1972, 1974, 1978, 1982, 1985, 1989, 1993, 1997, 1999, 2000, 2003, 2004, 2007, 2008, 2012]
ntrans = [0.0025, 0.005, 0.029, 0.12, 0.275, 1.18, 3.1, 7.5, 24.0, 42.0, 220.0, 592.0, 1720.0, 2046.0, 3100.0]

ntrans = pylab.array(ntrans)*1e6

y0, n0 = year[0], ntrans[0]

y = pylab.linspace(y0, year[-1], year[-1] - y0 + 1)
T2 = 2.
moore = pylab.log10(n0) + (y-y0) / T2 * pylab.log10(2)
pylab.plot(year, pylab.log10(ntrans), '*', markersize=12, color='r', markeredgecolor='r', label='observed')
pylab.plot(y, moore, linewidth=2, color='k', linestyle='--', label='predicted')
pylab.legend(fontsize=16, loc='upper left')
pylab.xlabel('Year',fontsize=16)
pylab.ylabel('log(ntrans)', fontsize=16)
pylab.title("Moore's law")
pylab.show()

# %%
years = range(2000, 2010)
divorce_rate = [5.0, 4.7, 4.6, 4.4, 4.3, 4.1, 4.2, 4.2, 4.2, 4.1]
margarine_consumption = [8.2, 7, 6.5, 5.3, 5.2, 4, 4.6, 4.5, 4.2, 3.7]

line1 = pylab.plot(years, divorce_rate, 'b-o', label='Divorce rate in Maine')
pylab.ylabel("Divorces per 1000 people")
pylab.legend()

pylab.twinx()
line2 = pylab.plot(years, margarine_consumption, 'r-o', label="Margarine consumption")
pylab.ylabel("lb of margarine per capita")

lines = line1 + line2
labels = []
for line in lines:
    labels.append(line.get_label())
pylab.legend(lines, labels)
pylab.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fb8652ef7eb4> in <module>
#       3 margarine_consumption = [8.2, 7, 6.5, 5.3, 5.2, 4, 4.6, 4.5, 4.2, 3.7]
#       4
# ----> 5 line1 = pylab.plot(years, divorce_rate, 'b-o', label='Divorce rate in Maine')
#       6 pylab.ylabel("Divorces per 1000 people")
#       7 pylab.legend()
#
# NameError: name 'pylab' is not defined
